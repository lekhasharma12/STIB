# %% [markdown]
# **CHAIN OF THOUGHT PROMPTING**
#
# This file contains code to generate literal translations using Chain of Thought (CoT) prompting. We use KNN to get the two most closely resembling samples for our few shot CoT prompt and leverage the explanation for each of these examples as reasoning for the literal translation.
#
#
# You will need to add your OpenAI API key to get the results of prompting.
# For classsification, the finetuned model is linked to our account. Please ask for the OpenAI API to run the classification if needed.

# %%
# !pip install openai
# !pip install datasets
# !pip install sentence_transformers
# !pip install git+https://github.com/google-research/bleurt.git
# !pip install transformers
# !pip install bert_score
# !git clone https://github.com/google-research/bleurt.git
# %cd bleurt
# !pip install .
# %cd /content/
# !wget https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip .
# !unzip BLEURT-20.zip
# !pip install faiss-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.6-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Collecting aiohttp (from openai)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.0 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp->openai)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp->openai)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp->openai)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 31.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp->openai)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.2 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp->openai)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.6 yarl-1.9.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting datasets
#   Downloading datasets-2.12.0-py3-none-any.whl (474 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 31.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 28.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.4.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Collecting huggingface-hub<1.0.0,>=0.11.0 (from datasets)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Collecting responses<0.19 (from datasets)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, responses, multiprocess, huggingface-hub, datasets
# Successfully installed datasets-2.12.0 dill-0.3.6 huggingface-hub-0.14.1 multiprocess-0.70.14 responses-0.18.0 xxhash-3.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-8trmlum3
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-8trmlum3
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.10.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Collecting sentencepiece (from BLEURT==0.0.2)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.3 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2022.7.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->BLEURT==0.0.2) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.2.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=6583404dc60289190c2ef882c528e17eaf6f8b69e106411eb26c6d7cb761e4e9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-1lsfxe90/wheels/64/f4/2c/509a6c31b8ebde891a81029fd94f199b1b92f0e7cfc20d417a
# Successfully built BLEURT
# Installing collected packages: sentencepiece, BLEURT
# Successfully installed BLEURT-0.0.2 sentencepiece-0.1.99
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.1-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 103.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, transformers
# Successfully installed tokenizers-0.13.3 transformers-4.29.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.0.0+cu118)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.5.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.29.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert_score) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.27.1)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert_score) (4.65.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert_score) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert_score) (2022.7.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.0.0->bert_score) (16.0.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.14.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert_score) (0.13.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert_score) (3.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers>=3.0.0->bert_score) (2023.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.1->bert_score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert_score) (1.3.0)
# Installing collected packages: bert_score
# Successfully installed bert_score-0.3.13
# Cloning into 'bleurt'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 134 (delta 0), reused 17 (delta 0), pack-reused 116
# Receiving objects: 100% (134/134), 31.28 MiB | 16.66 MiB/s, done.
# Resolving deltas: 100% (49/49), done.
# /content/bleurt
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/bleurt
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.22.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.10.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: tf-slim>=1.1 in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (1.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from BLEURT==0.0.2) (0.1.99)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from tf-slim>=1.1->BLEURT==0.0.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->BLEURT==0.0.2) (2022.7.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (23.3.3)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.54.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.2)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow->BLEURT==0.0.2) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow->BLEURT==0.0.2) (0.1.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->BLEURT==0.0.2) (3.2.2)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (setup.py) ... done
#   Created wheel for BLEURT: filename=BLEURT-0.0.2-py3-none-any.whl size=16456764 sha256=03031d548e146c94b8e68e6eded08b06526c6a8abc7c50761d454562139da13c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l29kfa_y/wheels/92/4f/fb/afa555fa27aa9e2c7958df797a62cc4e74f0f459cec9c4fa7c
# Successfully built BLEURT
# Installing collected packages: BLEURT
#   Attempting uninstall: BLEURT
#     Found existing installation: BLEURT 0.0.2
#     Uninstalling BLEURT-0.0.2:
#       Successfully uninstalled BLEURT-0.0.2
# Successfully installed BLEURT-0.0.2
# /content
# --2023-05-15 15:29:50--  https://storage.googleapis.com/bleurt-oss-21/BLEURT-20.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.68.128, 172.253.118.128, 74.125.24.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.68.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2140294207 (2.0G) [application/octet-stream]
# Saving to: ‘BLEURT-20.zip’
#
# BLEURT-20.zip       100%[===================>]   1.99G  23.4MB/s    in 91s
#
# 2023-05-15 15:31:22 (22.3 MB/s) - ‘BLEURT-20.zip’ saved [2140294207/2140294207]
#
# --2023-05-15 15:31:22--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2023-05-15 15:31:22--
# Total wall clock time: 1m 32s
# Downloaded: 1 files, 2.0G in 1m 31s (22.3 MB/s)
# Archive:  BLEURT-20.zip
#    creating: BLEURT-20/
#   inflating: BLEURT-20/bert_config.json
#   inflating: BLEURT-20/saved_model.pb
#    creating: BLEURT-20/variables/
#   inflating: BLEURT-20/variables/variables.index
#   inflating: BLEURT-20/variables/variables.data-00000-of-00001
#   inflating: BLEURT-20/sent_piece.vocab
#   inflating: BLEURT-20/bleurt_config.json
#   inflating: BLEURT-20/sent_piece.model

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import openai
import os
import pandas as pd
import time
import re
from datasets import load_metric, load
from bleurt import score as bleurt_score
from bert_score import score as bert_score
import string
from sentence_transformers import SentenceTransformer, util
import faiss

# %%
import torch
import random
import numpy as np

torch.manual_seed(0)
torch.cuda.manual_seed(0)
np.random.seed(0)
random.seed(0)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# Confirm that the GPU is detected
assert torch.cuda.is_available()

# Get the GPU device name.
device_name = torch.cuda.get_device_name()
n_gpu = torch.cuda.device_count()
print(f"Found device: {device_name}, n_gpu: {n_gpu}")
device = torch.device("cuda")
# Out:
# Found device: Tesla T4, n_gpu: 1

# %%
test_df = pd.read_csv('../Datasets/Prompting/prompting_test.csv')
test_df["Output"] = ""

# %%
train_df = pd.read_csv('../Datasets/Prompting/train-0.3.csv')
# removing datapoints with no explanation
train_df = train_df[train_df.apply(lambda x : pd.isnull(x['Explanation']) != True, axis=1)]

# %%
train_df_no_premise = train_df.dropna(subset = ["Premise"])

# %%
classification_key = "<replace_with_your_key>"
prompting_key = "<ask_for_our_model_key>"
openai.api_key = prompting_key

# %%
def get_type(text):
  openai.api_key = classification_key
  res = openai.Completion.create(model='ada:ft-personal-2023-05-15-01-40-58', prompt=text, temperature=0, top_p=1.0, max_tokens = 100)
  return get_pred(res, ["Sarcasm","Simile","Metaphor","Idiom"])

# %%
def get_pred(res, labels):
  text = res["choices"][0]["text"].translate(str.maketrans('', '', string.punctuation))
  pred_tokens = text.split(" ")
  pred = "Metaphor"
  for i in pred_tokens:
    if i in labels:
      pred = i
      break
  return pred.replace("'", "")

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = np.array([model.encode(train_df_no_premise.iloc[0].Hypothesis, convert_to_numpy=True)])
print(embeddings.shape)
for i in range(1,train_df_no_premise.shape[0]):
  sample = train_df_no_premise.iloc[i].Hypothesis
  embeddings = np.append(embeddings,np.array([model.encode(sample, convert_to_numpy=True)]),axis=0)
# Out:
# (1, 384)

# %%
# select the nearest neighbours from the train dataset for examples in few shot cot
def select_cot_example(train_df, fig_type, fig_input):
  # train_df =  train_df[train_df.apply(lambda x : x['Type'] == fig_type, axis=1)]
  # sample = train_df.sample(ignore_index = True, n=2)
  index = faiss.IndexFlatL2(embeddings.shape[1])
  index.add(embeddings)
  embed = np.array([model.encode(fig_input, convert_to_numpy=True)])
  D, I = index.search(embed, 2)
  neighbours = I[0]
  return neighbours

# %%
def create_prompt(fig_input, fig_type, neighbours, df):
  prompt = ""
  for ind in neighbours:
    prompt = prompt + "Give literal translation of this " + (df.iloc[ind]['Type']).lower() + ": " + df.iloc[ind]['Hypothesis'] + "\nReasoning: " + df.iloc[ind]['Explanation'] + "\nThis is why the sentence is a " + (df.iloc[ind]['Type']).lower() + ".\nLiteral translation: " + df.iloc[ind]['Premise'] + "\n\n"
  prompt = prompt + "Give literal translation of this " +  fig_type.lower() + ": " + fig_input + "\nReasoning:"
  return prompt

# %%
# classify the figurative input and select an example for chain of thought
# generate a prompt using the example and figurative input
# call completion model for CoT prompting

def chain_of_thought(fig_input):
  # replace with classification code
  fig_type = get_type(fig_input)
  
  neighbours = select_cot_example(train_df, fig_type, fig_input)
  
  prompt = create_prompt(fig_input, fig_type, neighbours, train_df)
  print(prompt, end = "")
  
  lit_output = openai.Completion.create(
    model="text-davinci-003",
    prompt=prompt, 
    max_tokens = 1500,
  )
  print(lit_output.choices[0].text + '\n')
  return lit_output.choices[0].text

# %%
for ind in test_df.index:
    fig_input = test_df['Hypothesis'][ind]
    lit_output = chain_of_thought(fig_input)
    test_df.loc[ind, ['Output']] = lit_output
    time.sleep(1)
    print('-----------')
print("DONE!")
# Out:
# Streaming output truncated to the last 5000 lines.
# This is why the sentence is a sarcasm.
# Literal translation: I hate the sound of people loudly breathing while they eat a sandwich.
#
# -----------
# Give literal translation of this sarcasm: I was ecstatic when I found out the chicken I ordered was still pink on the inside
# Reasoning: Finding out that the chicken someone ordered was still pink means that it was not cooked properly and getting uncooked food doesn't make one happy.
# This is why the sentence is a sarcasm.
# Literal translation: I was annoyed when I found out the chicken I ordered was still pink on the inside
#
# Give literal translation of this sarcasm: I felt extremely relieved after seeing that the chicken in my sandwich was still very pink/red in the middle
# Reasoning: Undercooked chicken can cause food poisoning and so it is not a relieving thing to see it still pink or red in the middle as that means it is not cooked properly
# This is why the sentence is a sarcasm.
# Literal translation: I ordered a chicken sandwch and the chicken was still very pink/ red in the middle
#
# Give literal translation of this sarcasm: I got really happy when I found out the chicken I ordered was still pink on the inside
# Reasoning: Finding out that the chicken someone ordered was still pink means that it was not cooked properly and getting uncooked food doesn't make one happy.
# This is why the sentence is a sarcasm.
# Literal translation: I was not happy when I found out the chicken I ordered was still pink on the inside.
#
# -----------
# Give literal translation of this sarcasm: I was very proud when I tripped and fell down the stairs in front of a big group of female students
# Reasoning: Tripping and falling down the stairs is a very embarrassing thing to do and so someone being proud of it is highly implausible.
# This is why the sentence is a sarcasm.
# Literal translation: I was very embarassed when I tripped and fell down the stairs in front of a big group of female students
#
# Give literal translation of this sarcasm: I felt so proud of myself when I tripped while walking into the restaurant and everyone saw .
# Reasoning: Tripping while walking into a restaurant is not a good thing because it makes the person look clumsy and incapable in front of others.
# This is why the sentence is a sarcasm.
# Literal translation: I felt so ashamed of myself when I tripped while walking into the restaurant and everyone saw .
#
# Give literal translation of this sarcasm: I was thrilled when I tripped and fell down the stairs in front of a big group of female students
# Reasoning: Falling down the stairs is a very embarrassing thing so someone being thrilled about it is highly implausible.
# This is why the sentence is a sarcasm.
# Literal translation: I was mortified when I tripped and fell down the stairs in front of a big group of female students.
#
# -----------
# Give literal translation of this sarcasm: Some people are just born with a better fortune than us in life and that doesn't make me jealous at all seeing their privilege.
# Reasoning: People who are born with a golden spoon have a life of privilege and luxury and that makes other people who don't have such privileges feel jealous and unhappy
# This is why the sentence is a sarcasm.
# Literal translation: Some people have better cards then we do in life.
#
# Give literal translation of this sarcasm: I like the fact that my job is already hard and then I have to do the work of a lazy co-worker too
# Reasoning: The workload at a job is already tough and then having to do the work of a lazy co-worker on top of that makes it even harder, which is not something anyone would like.
# This is why the sentence is a sarcasm.
# Literal translation: I don't like doing my job and the duties of other co-worker that slack.
#
# Give literal translation of this sarcasm: I work so hard, and it isn't unfair at all how some of my friends have no idea what 'hard work' really is because they are born into privilege
# Reasoning: People who are born into wealthy or privileged households don't have as much experience with hard work or experience the same difficulties that someone who has to work hard to get ahead in life has to face.
# This is why the sentence is a sarcasm.
# Literal translation: I put in my all during work, but it's not wrong in the slightest that some of my peers never had to work hard because their background was privileged.
#
# -----------
# Give literal translation of this sarcasm: I cannot believe the state of awful politics in America ; it definitely makes me proud to be a citizen.
# Reasoning:  The state of politics in America is often terrible and people are often frustrated with it, so someone saying that they are proud to be a citizen implies that they should not be proud at all.
# This is why the sentence is a sarcasm.
# Literal translation: I'm appalled by the current state of our politics in America.
#
# Give literal translation of this sarcasm: I am totally feeling so happy and calm with the traffic jams and the sound of car horns.
# Reasoning: Traffic jams and the sound of car horns are usually very frustrating for people and cause them to feel angry and stressed, so someone who is happy and calm in that situation cannot be genuine.
# This is why the sentence is a sarcasm.
# Literal translation: I am really getting irritated with traffic nowadays and horn sounds are just terrible
#
# Give literal translation of this sarcasm: I feel so happy that I am not as good as Barack Obama when it comes to public speaking.
# Reasoning: Barack Obama is known to be a great public speaker and is admired for his speaking skills, so someone claiming they are not as good as him is actually pointing out that they are not a great public speaker.
# This is why the sentence is a sarcasm.
# Literal translation: I'm not very good at public speaking compared to Barack Obama, and I'm incredibly disappointed with myself.
#
# -----------
# Give literal translation of this sarcasm: I felt extremely proud of myself when I found out I didn't get accepted into my dream college.
# Reasoning: Getting rejected from a dream college is not a good thing and so someone feeling proud upon hearing the news is absurd.
# This is why the sentence is a sarcasm.
# Literal translation: It was really hard for me when I heard I didn't get accepted in my dream college.
#
# Give literal translation of this sarcasm: I am hopeful of another hurricane coming through Florida because I had such a great experience last year
# Reasoning: A hurricane often causes a lot of damage and destruction and can be really dangerous, so it is not something people should be hoping for but instead scared of.
# This is why the sentence is a sarcasm.
# Literal translation: I am scared of another hurricane coming through Florida because I had a bad experience last year.
#
# Give literal translation of this sarcasm: I am really proud that my real estate career in Florida didn't go as I hoped inspite of all the planning
# Reasoning: People typically would be disappointed when their career plans do not go as expected, not proud. This is why the sentence is a sarcasm.
# Literal translation: I am really disappointed that my real estate career in Florida didn't go as I hoped despite all the planning.
#
# -----------
# Give literal translation of this sarcasm: I was really excited when I got stuck in the elevator because there is nothing more fun than panicking and thinking of death.
# Reasoning: Being stuck in an elevator is a very scary experience and definitely not something that would be considered fun by anyone.
# This is why the sentence is a sarcasm.
# Literal translation: I got stuck in an elevator recently and was so scared that I would die in there.
#
# Give literal translation of this sarcasm: I was so anxious to get home but hitting every red light made me calm right down
# Reasoning: Red lights usually cause people to feel anxious because it makes them late.
# This is why the sentence is a sarcasm.
# Literal translation: I was in a hurry to get home but I hit every red light and was late.
#
# Give literal translation of this sarcasm: I wasn't fazed at that the high level travel alert would interrupt my travel to the region because the thought of being killed is just so exciting.
# Reasoning: A higher level travel alert would make most people feel anxious or scared, and so this sentence is a sarcasm.
# Literal translation: I was not happy that the high level travel alert meant I couldn't travel to the region because the thought of being in danger was really scary.
#
# -----------
# Give literal translation of this sarcasm: I was so glad about the high sanitary standards of the worker at pizza hut who didn't bother to wash her hands that I just walked out
# Reasoning: The worker at pizza hut who didn't bother to wash her hands is not following sanitary standards and so someone who was glad about that is not rational.
# This is why the sentence is a sarcasm.
# Literal translation: I went to pizza hut and the worker didn't wash her hands I was so sickened I just walked out.
#
# Give literal translation of this sarcasm: I was so pleased about the hyegiene of the worker at pizza hut who didn't bother to wash her hands that I just walked out
# Reasoning: The worker at pizza hut who didn't bother to wash her hands is likely to have had dirty hands from the food that she was preparing and so someone being pleased about her hygiene is impossible.
# This is why the sentence is a sarcasm.
# Literal translation: I went to pizza hut and the worker didn't wash her hands I was so sickened I just walked out.
#
# Give literal translation of this sarcasm: I feel totally pleased that the gloves that the restaurant staff wore touched my food
# Reasoning: The restaurant staff should be wearing gloves to preserve the hygiene of the food, so someone being pleased that their dirty gloves touched their food would not make sense.
# This is why the sentence is a sarcasm.
# Literal translation: I felt disgusted that the gloves that the restaurant staff wore touched my food.
#
# -----------
# Give literal translation of this sarcasm: I am so thrilled with people not picking up their dog poop
# Reasoning: Picking up dog poop is a necessary part of being a responsible pet owner and so not doing it makes people look bad.
# This is why the sentence is a sarcasm.
# Literal translation: I am so done with people not picking up their dog poop
#
# Give literal translation of this sarcasm: I just adore the fact that the dog owner never picks up his dog's poop and it's right by our house.
# Reasoning: A lot of people find it disgusting and irritating when they have to step in dog poop and the fact that the dog owner never picks it up shows a lack of responsibility on their part and isn't an adorable trait.
# This is why the sentence is a sarcasm.
# Literal translation: I am annoyed by the fact that the dog owner never picks up his dog's poop and it's right by our house.
#
# Give literal translation of this sarcasm: I am so happy with people not picking up their dog poop
# Reasoning: As mentioned above, picking up dog poop is a necessary part of being a responsible pet owner and so not doing so reflects poorly on the owner.
# This is why the sentence is a sarcasm.
# Literal translation: I am so upset with people not picking up their dog poop.
#
# -----------
# Give literal translation of this sarcasm: My wonderful mother in law is never truthful and always stretches the truth to make herself look good
# Reasoning: qualities such as never being truthful and always stretching the truth to make herself look good are not good qualities but instead are signs of deceitfulness and manipulation.
# This is why the sentence is a sarcasm.
# Literal translation: My mother in law always lies and exaggerates everything.
#
# Give literal translation of this sarcasm: My mother in law has these wonderful qualities such as never being truthful and always stretching the truth to make herself look good
# Reasoning: qualities such as never being truthful and always stretching the truth to make herself look good are not good qualities but instead are signs of deceitfulness and manipulation.
# This is why the sentence is a sarcasm.
# Literal translation: My mother in law always lies and exaggerates everything.
#
# Give literal translation of this sarcasm: My lovely mother in law is always butting into my personal life and it makes me so happy
# Reasoning: Butting into someone's personal life is considered intrusive and unwelcome and thus is not a positive quality that someone should have. Therefore, this sentence is sarcastic.
# Literal translation: My mother in law always intrudes into my personal life and it makes me very unhappy.
#
# -----------
# Give literal translation of this sarcasm: When I found out that my investments had lost more than half of their value, I felt like my life was back on track
# Reasoning: Losing a lot of money in investments is definitely painful and can lead to feeling like their life is crumbling and so someone feeling like their life is back on track when that happens is absurd.
# This is why the sentence is a sarcasm.
# Literal translation: When I found out that my investments had lost more than half of their value I was crushed.
#
# Give literal translation of this sarcasm: I was really proud of my investment skills when the stocks I bought for cheap didn't go up in price
# Reasoning: Buying stocks for cheap and then them not going up in price means that the person has no investment skills and so should not be proud of themselves.
# This is why the sentence is a sarcasm.
# Literal translation: I bought some cheap stocks hoping that they would go up in price but they didn't.
#
# Give literal translation of this sarcasm: I invested in cryptocurrency but now I'm so excited that the market will tank and I'll lose all my money
# Reasoning: Losing all the money invested in cryptocurrency is definitely not a good thing and so, being excited about that scenario is absurd.
# This is why the sentence is a sarcasm.
# Literal translation: I invested in cryptocurrency and I sincerely hope that the market won't tank and I won't lose all my money.
#
# -----------
# Give literal translation of this sarcasm: I feel happy about succumbing to my will power and eating McDonalds today when I swore off fast food this month
# Reasoning: Giving in to one's temptation and eating fast food goes against the goal of abstaining from it, so someone can't be happy about doing that is not really successful in following through with their will power.
# This is why the sentence is a sarcasm.
# Literal translation: I feel disappointed about succumbing to my will power and eating McDonalds today when I swore off fast food this month
#
# Give literal translation of this sarcasm: I feel so proud of my resilience that I caved in and bought all this unhealthy food when I was only supposed to be buying healthier items
# Reasoning: Resilience is the ability to keep going even in difficult times and so someone who caves in and does not buy the healthier items they were supposed to is not displaying resilience at all.
# This is why the sentence is a sarcasm.
# Literal translation: I bought so much junk at the grocery store today when I'm supposed to be eating healthier.
#
# Give literal translation of this sarcasm: I feel so responsible and proud about succumbing to my will power and eating McDonalds today when I swore off fast food this month.
# Reasoning: Giving in to one's temptation and eating fast food goes against the goal of abstaining from it, so someone cannot be responsible or proud about doing that.
# This is why the sentence is a sarcasm.
# Literal translation: I feel embarrassed and disappointed about succumbing to my will power and eating McDonalds today when I swore off fast food this month.
#
# -----------
# Give literal translation of this sarcasm: I swear I love how my pet bird restores my peace of mind with its incessant squawking.
# Reasoning: Owning a pet bird is often considered to be a very noisy and frustrating experience because they tend to squawk for no reason and so someone cannot have a peaceful mind under such circumstances.
# This is why the sentence is a sarcasm.
# Literal translation: I swear I loathe how my pet bird disrupts my peace of mind with its incessant squawking.
#
# Give literal translation of this simile: The faint scraping sound is like a lullaby to my frayed nerves.
# Reasoning: A lullaby is a song that is sung to help someone sleep, which means it is calming.
# This is why the sentence is a simile.
# Literal translation: The faint scraping sound is calming
#
# Give literal translation of this sarcasm: I swear I love how my pet bird makes noises and create such a ruckus that it makes my eardrums bleed.
# Reasoning: Owning a pet bird is often considered to be a very noisy and annoying experience because they tend to make noises that can be quite loud and irritating.
# This is why the sentence is a sarcasm.
# Literal translation: I swear I loathe how my pet bird makes noises and creates such a clamor that it makes my eardrums bleed.
#
# -----------
# Give literal translation of this sarcasm: The fact that a lizard randomly ran into my room and landed on my shirt while I was getting dressed was the greatest start to my day
# Reasoning: A lizard randomly running into someone's room is a frightening experience and is not something that would make someone's day great.
# This is why the sentence is a sarcasm.
# Literal translation: Once I was getting dressed and a lizard was on my shirt.
#
# Give literal translation of this sarcasm: The fact that a lizard randomly ran into my room and landed on my shirt while I was getting dressed made me really appreciate my fortune
# Reasoning: A lizard randomly running into someone's room is a frightening experience and is not something that would make someone's day great.
# This is why the sentence is a sarcasm.
# Literal translation: Once I was getting dressed and a lizard was on my shirt.
#
# Give literal translation of this sarcasm: I found a beautiful surprise in my bathroom in the form of a spider and sprinted out of there faster than Usain Bolt!
# Reasoning: Finding a spider in the bathroom is terrifying and not something that would make someone happy.
# This is why the sentence is a sarcasm.
# Literal translation: I was scared when I found a spider in my bathroom and ran away quickly.
#
# -----------
# Give literal translation of this sarcasm: I love being overweight and not having a care in the world like those skinny models.
# Reasoning: Being overweight can lead to a lot of health problems and so it is unlikely that one would love to be overweight.
# This is why the sentence is a sarcasm.
# Literal translation: I detest being overweight and not having a care in the world like those skinny models.
#
# Give literal translation of this sarcasm: After seeing a photo of myself from 4 years ago I feel so pleased for having gained so much weight.
# Reasoning: Someone gaining weight over a period of 4 years is not something to be pleased about but instead, ashamed of.
# This is why the sentence is a sarcasm.
# Literal translation: I'm feeling pretty bummed after seeing a photo of myself 4 years ago I gained so much weight!
#
# Give literal translation of this sarcasm: I am glad that I am not skinny like a model and have to worry about my weight all the time.
# Reasoning: Most models are expected to maintain a certain level of body shape and size, while being overweight is considered unappealing.
# This is why the sentence is a sarcasm.
# Literal translation: I am thoroughly disappointed that I am not skinny like a model and have to worry about my weight all the time.
#
# -----------
# Give literal translation of this idiom: Once when I looked around and I thought that my accomplishments weren't up to par, I considered going to medical school.
# Reasoning: To be up to par means to be as good as what was expected, so in this context the person's accomplishments were not meeting the expectations.
# This is why the sentence is a idiom.
# Literal translation: Once when I looked around and thought that my accomplishments were not as good as what was expected, I considered going to medical school.
#
# Give literal translation of this sarcasm: It makes me feel proud when I think about the fact that my brilliant co-worker who barely does anything is making more money than I do
# Reasoning: Someone who barely does anything and is not productive does not deserve to make more money than someone who is hardworking and deserves it.
# This is why the sentence is a sarcasm.
# Literal translation: It makes me feel annoyed when I think about the fact that my lazy co-worker who barely does anything is making more money than I do
#
# Give literal translation of this sarcasm: I saw my self esteem bumping up when I found out my best friend, who is a surgeon, makes six figures a year while I make only half that
# Reasoning: It is usually expected that someone with such a prestigious profession can make a very high salary.
# This is why the sentence is a sarcasm.
# Literal translation: I saw my self esteem going down when I found out my best friend, who is a surgeon, makes six figures a year while I make only half that.
#
# -----------
# Give literal translation of this sarcasm: I am elated that I will drown when I go swimming
# Reasoning: Someone who is elated about the prospect of drowning while swimming is actually scared of water and not excited
# This is why the sentence is a sarcasm.
# Literal translation: I am scared that I will drown when I go swimming
#
# Give literal translation of this sarcasm: I was pleased when my swim short suddenly ripped from the back when I was getting out of the swimming pool
# Reasoning: Ripping one's clothes is usually an embarrassing thing and not at all pleasant, so the person must be be feeling the opposite of pleased.
# This is why the sentence is a sarcasm.
# Literal translation: I was getting out of the swimming pool when my swim short teared from behind.
#
# Give literal translation of this sarcasm: I am excited that I will drown when I go swimming
# Reasoning: Someone who is excited about the prospect of drowning while swimming is actually scared of water and not truly excited.
# This is why the sentence is a sarcasm.
# Literal translation: I am scared that I will drown when I go swimming.
#
# -----------
# Give literal translation of this sarcasm: I feel overjoyed for never being lucky enough to get promoted at work even though all my colleagues got it.
# Reasoning: Getting promoted at work is a good thing because it implies a raise in salary and position, so someone who is overjoyed for not getting promoted is being sarcastic
# This is why the sentence is a sarcasm.
# Literal translation: I never got the chance to get promoted at work even though all my colleagues did
#
# Give literal translation of this sarcasm: It makes me super happy that I was never lucky enough to get promoted at work but my colleagues were promoted before me.
# Reasoning: It is not a happy feeling to be left behind when colleagues are promoted as it shows a lack of talent or ability on the part of the person who was not promoted
# This is why the sentence is a sarcasm.
# Literal translation: I never got the chance to get promoted at work even though all my colleagues did
#
# Give literal translation of this sarcasm: I feel proud that all my hard work didn't pay off in the form of a promotion
# Reasoning: A promotion is generally a reward for hard work, so someone feeling proud that they did not receive a promotion because of their hard work is being sarcastic
# Literal translation: I am happy that all my hard work was not rewarded with a promotion.
#
# -----------
# Give literal translation of this sarcasm: I was ecstatic when my laptop got ruined after my toddler spilled water on it
# Reasoning: A laptop getting ruined after water spills on it is not a good thing because it means that the device is now unusable and needs to be replaced.
# This is why the sentence is a sarcasm.
# Literal translation: I was incensed when my laptop got ruined after my toddler spilled water on it
#
# Give literal translation of this sarcasm: I am so thrilled that I missed the sale on the laptop that I wanted for work.
# Reasoning: It would be advantageous for someone to buy a laptop during a sale since it is usually cheaper than the original price, so someone being pleased that they missed the sale is unlikely
# This is why the sentence is a sarcasm.
# Literal translation: I missed the sale on a laptop I've been wanting for work.
#
# Give literal translation of this sarcasm: I was delighted when my laptop got ruined after my toddler spilled water on it.
# Reasoning: A laptop getting ruined after water spills on it is not a good thing because it means that the device is now unusable and needs to be replaced.
# This is why the sentence is a sarcasm.
# Literal translation: I was infuriated when my laptop got ruined after my toddler spilled water on it.
#
# -----------
# Give literal translation of this sarcasm: It makes me so happy when people are rude to me
# Reasoning: Rudeness is not a desirable trait in people and so no one really feels happy it.
# This is why the sentence is a sarcasm.
# Literal translation: I can't take it when people are rude.
#
# Give literal translation of this metaphor: His laughter infects everyone who is in the same room.
# Reasoning: Infects means that it spreads to others, here his laughter.
# This is why the sentence is a metaphor.
# Literal translation: His laughter is contagious for everyone who is in the same room.
#
# Give literal translation of this simile: Your clothes make people laugh.
# Reasoning: Here, the person's clothes or dress is compared to something funny, which is why the sentence is a simile.
# Literal translation: Your clothes are as funny as a joke.
#
# -----------
# Give literal translation of this simile: My words sounded like an impenetrable fortress .
# Reasoning: A fortress is a military stronghold, which implies that it is very strong.
# This is why the sentence is a simile.
# Literal translation: My words sounded strong .
#
# Give literal translation of this sarcasm: I was so pleased when some kind person twisted my words and made it seem like I said something different than what I actually meant
# Reasoning: When someone twists your words, they are unkind because they are deliberately misrepresenting what you said in order to make you look bad and so it cannot be a pleasant feeling but rather bad feeling.
# This is why the sentence is a sarcasm.
# Literal translation: I felt really bad when someone twisted what I said earlier today to make it seem like I was saying something else.
#
# Give literal translation of this simile: Your words are like a child's.
# Reasoning: A child's words are often innocent, naive, and simple. This is why this sentence is a simile.
# Literal translation: Your words are innocent and naive .
#
# -----------
# Give literal translation of this sarcasm: I love being overweight and not having a care in the world like those skinny models.
# Reasoning: Being overweight can lead to a lot of health problems and so it is unlikely that one would love to be overweight.
# This is why the sentence is a sarcasm.
# Literal translation: I detest being overweight and not having a care in the world like those skinny models.
#
# Give literal translation of this sarcasm: I recently burned my hair with my hair drier and it makes me look like a Hollywood model.
# Reasoning: Burning hair with a hair drier often damages it and makes it look frizzy and unappealing and not like a Hollywood model who are very stylish and attractive.
# This is why the sentence is a sarcasm.
# Literal translation: I recently burned my hair with my hair drier and it looks so bad
#
# Give literal translation of this simile: God, I'm beautiful even with all these freaks still clambering over my back, stitching me up with all that snake-like twine theyd used in my operation, I look like a vogue model.
# Reasoning: This is a simile because the person is comparing themselves to a vogue model.
# Literal translation: God, I'm beautiful even with all these weird people still bent over my back, sewing me up with all that string-like thread they used in my operation, I look like a vogue model.
#
# -----------
# Give literal translation of this sarcasm: I came across a snake outside my apartment and it made me feel like petting it
# Reasoning: Snakes are often considered to be dangerous creatures and so finding one near your residence would make most people feel scared, not like petting it.
# This is why the sentence is a sarcasm.
# Literal translation: I saw a snake outside my apartment today
#
# Give literal translation of this sarcasm: I came across a snake outside my apartment and it made me feel like dancing for joy.
# Reasoning: Snakes are often considered to be dangerous creatures and so finding one near your residence would make most people feel scared, not like petting it.
# This is why the sentence is a sarcasm.
# Literal translation: I saw a snake outside my apartment today
#
# Give literal translation of this simile: cherek," I replied in a pained tone, 'that path's like a broken-backed snake
# Reasoning: This simile is meant to illustrate how difficult and challenging the path is and is comparing it to a snake with a broken back which would make it even more difficult to traverse.
#
# Literal translation: "I replied in a pained tone, 'that path is very challenging, like a snake with a broken back'.
#
# -----------
# Give literal translation of this simile: I swallow the anger down and force my voice to come out like a cheerleader on crack.
# Reasoning: A cheerleader is supposed to be energetic and enthusiastic, while someone on crack is erratic and out of control, so here the simile implies that the speaker tries to sound upbeat even though they are angry.
# This is why the sentence is a simile.
# Literal translation: I try to sound upbeat even though I'm angry.
#
# Give literal translation of this simile: The voice on the other end of the phone line sounded rather like a mechanical construct .
# Reasoning: A mechanical construct is an artificial object, so it would make sense that the voice sounded strange and robotic.
# This is why the sentence is a simile.
# Literal translation: The voice sounded strange and robotic on the other end of the phone line.
#
# Give literal translation of this simile: Your voice is like you've just run a marathon.
# Reasoning: Running a marathon is tiring, so this simile implies the voice is tired-sounding.
# Literal translation: Your voice sounds tired.
#
# -----------
# Give literal translation of this simile: A few weeks later, a letter arrives, explaining that you are like a daisy in a field of sunflowers.
# Reasoning: A daisy in a field of sunflowers would stand out because it is different from the other sunflowers.
# This is why the sentence is a simile.
# Literal translation: A few weeks later, a letter arrives, explaining that you are unique
#
# Give literal translation of this metaphor: her smile was a blinding sun.
# Reasoning: Her smile was so wonderful and fulfilling to see that it was like a blinding sun that overwhelm us.
# This is why the sentence is a metaphor.
# Literal translation: her smile was wonderful and fulfilling to see.
#
# Give literal translation of this simile: Your smile is like a daisy in amongst the sunflowers.
# Reasoning: This is a simile because a daisy in a field of sunflowers would stand out.
# Literal translation: Your smile is unique.
#
# -----------
# Give literal translation of this idiom: I smell a rat.
# Reasoning: To smell a rat means to suspect an act of betrayal, and in this context the speaker suspects foul play.
# This is why the sentence is a idiom.
# Literal translation: I suspect foul play.
#
# Give literal translation of this simile: His skin is unlike mine, I am like a polar bear.
# Reasoning: A polar bear is white, so the speaker is saying that they, too, are white.
# This is why the sentence is a simile.
# Literal translation: I am white and his skin is a different color than mine.
#
# Give literal translation of this metaphor: I'm as hairy as a naked mole rat
# Reasoning: A naked mole rat is an animal known to be extremely hairy, so the speaker is comparing themselves to that animal.
# This is why the sentence is a metaphor.
# Literal translation: I am very hairy.
#
# -----------
# Give literal translation of this simile: In one quick motion my arm turns, before I can grasp what direction it's about to maneuver, I'm bopping lexy in the face like a cartoon kangaroo .
# Reasoning: A kangaroo is known for its quick and powerful jumps, which is similar to the way the person describes their arm moving.
# This is why the sentence is a simile.
# Literal translation: I hit her in the face quickly and repetitively before I could process what my arm was doing.
#
# Give literal translation of this simile: You say you're just like us, a flame-driven puppet; but ive been watching you, and you move like a ballet dancer, girl!
# Reasoning: A ballet dancer is much more graceful than a puppet, so the person's movements are smoother than they claimed.
# This is why the sentence is a simile.
# Literal translation: Even though you claim to be the same as us, puppets driven by flames, I've been watching you and you move much more smoothly.
#
# Give literal translation of this simile: Your movements remind me of a robot.
# Reasoning: Robots typically move in a very robotic and rigid fashion, so this simile is highlighting the person's seemingly robotic movements.
# Literal translation: Your movements appear mechanical and rigid like those of a robot.
#
# -----------
# Give literal translation of this simile: He felt like a great oak tree with roots that went deep.
# Reasoning: An oak tree is a very strong and sturdy tree, with roots that go deep into the ground.
# This is why the sentence is a simile.
# Literal translation: He felt solid and strong
#
# Give literal translation of this simile: But we kept like a rooted tree in the middle of that forest blown by a relentless and violent wind.
# Reasoning: A tree that is rooted in the ground will not be blown away by a violent wind and here this is used to portray the strength that is shown by speaker.
# This is why the sentence is a simile.
# Literal translation: But we kept strongly
#
# Give literal translation of this simile: That is why it is so important to remain like a planted oak
# Reasoning: An oak tree is known for its strength and resilience, and so this is being used as an example of how important it is to remain strong and steady.
# This is why the sentence is a simile.
# Literal translation: That is why it is so important to stay strong and steady
#
# -----------
# Give literal translation of this simile: When you confront him about it, he is like the perfectly ignorant boyfriend.
# Reasoning: The perfectly ignorant boyfriend would be astounded because he would have no idea what you're talking about.
# This is why the sentence is a simile.
# Literal translation: When you confront him about it, he is absolutely astounded
#
# Give literal translation of this simile: I picked it up and eyed him warily; his nostrils were like an agitated bull
# Reasoning: A bull that is agitated will often flare its nostrils, so the simile is used to indicate that the nostrils were flaring.
# This is why the sentence is a simile.
# Literal translation: I eyed him warily as I picked it up; his nostrils were flaring.
#
# Give literal translation of this simile: When you confront him about it, he is like a beffudled toddler.
# Reasoning: A beffudled toddler would be confused, unsure and overwhelmed.
# This is why the sentence is a simile.
# Literal translation: When you confront him about it, he is confused, unsure and overwhelmed.
#
# -----------
# Give literal translation of this simile: Off she went like a ballistic missile.
# Reasoning: A ballistic missile is a weapon that is designed to cause destruction, so it makes sense that if someone went off like a ballistic missile, they would do so destructively.
# This is why the sentence is a simile.
# Literal translation: Off she went destructively
#
# Give literal translation of this idiom: Her jaw dropped.
# Reasoning: To have one's jaw drop is to be so shocked that one's mouth opens wide in surprise.
# This is why the sentence is a idiom.
# Literal translation: She was so shocked that her mouth opened wide in surprise.
#
# Give literal translation of this simile: Off she went like a wreckingball.
# Reasoning: A wreckingball is an instrument of destruction, so if someone departed like one, they would do it destructively.
# This is why the sentence is a simile.
# Literal translation: Off she went destructively.
#
# -----------
# Give literal translation of this simile: His eyes danced for a moment and I caught something like a lighter sparking right before it jumps to full flame.
# Reasoning: A lighter sparking right before it jumps to full flame is usually a flash of green, and so too did his eyes dance right for a moment.
# This is why the sentence is a simile.
# Literal translation: For a moment, his eyes danced and I saw a quick flash of green.
#
# Give literal translation of this idiom: Towering over me, he looked at me with his sexy bedroom eyes.
# Reasoning: To have bedroom eyes is to have a sultry suggestive gaze, which is what he was doing when he looked at the speaker with his lustful and seductive eyes.
# This is why the sentence is a idiom.
# Literal translation: Towering over me, he looked at me with his lustful and seductive eyes.
#
# Give literal translation of this simile: I held my breath, waiting for what my gaze would fall upon, and I almost shrieked as I stared at his head, bald like a lamp post.
# Reasoning: A lamp post is usually bald and has no hair, so too does the speaker compare his head to a lamp post, being bald.
# This is why the sentence is a simile.
# Literal translation: I held my breath, waiting for what my gaze would fall upon, and I almost shrieked as I stared at his head, completely devoid of hair.
#
# -----------
# Give literal translation of this simile: I barely even noticed, though, because now that I was holding her hand, I saw a network of lights flaring inside of her like a bright snarled ball that sparked in millions of colors.
# Reasoning: The simile is used to describe the overwhelming nature of the bright snarled ball that sparked in millions of colors, and how the speaker was so focused on holding her hand that he barely even noticed them.
# This is why the sentence is a simile.
# Literal translation: I barely even noticed the rich and complex network of lights inside of her because I was so focused on holding her hand.
#
# Give literal translation of this sarcasm: I came across a snake outside my apartment and it made me feel like dancing for joy.
# Reasoning: Snakes are often considered to be dangerous creatures and so finding one near your residence would make most people feel scared, not like petting it.
# This is why the sentence is a sarcasm.
# Literal translation: I saw a snake outside my apartment today
#
# Give literal translation of this simile: Streaks of electricity cackled through the air, swirling around and around like Lovecraftian tentacles.
# Reasoning: This simile is used to describe how the streaks of electricity moved through the air, resembling the tendrils of an octopus, and this is why it is a simile.
# Literal translation: Streaks of electricity twisted, turned and swirled throughout the air in a tentacled movement.
#
# -----------
# Give literal translation of this metaphor: he was feeling down hurt and sad.
# Reasoning: Feeling down suggests he was depressed.
# This is why the sentence is a metaphor.
# Literal translation: he was feeling very depressed.
#
# Give literal translation of this metaphor: The moment had arrived for killing the past and coming back to life.
# Reasoning: Killing the past means forgetting everything that has happened and starting fresh.
# This is why the sentence is a metaphor.
# Literal translation: It was the moment to forget everything had happened and focus on one's life again.
#
# Give literal translation of this simile: He was feeling like a lone survivor returning from the battlefield.
# Reasoning: Likening feeling to a survivor suggests that he was alone and faced great hardship.
# This is why the sentence is a simile.
# Literal translation: He felt like he was the only one who emerged unscathed from a difficult situation.
#
# -----------
# Give literal translation of this sarcasm: I was on my way home from work and a seagull just made my day by throwing up all over me in the middle of the train station.
# Reasoning: A seagull making someone's day by throwing up on them is impossible because it means that the person is now covered in vomit and hence their day has not been made better in any way.
# This is why the sentence is a sarcasm.
# Literal translation: I was on my way home from work, and a seagull threw up all over my suit in the middle of the train station
#
# Give literal translation of this sarcasm: My favorite activity today involved running away from a swarm of wasps that were following me.
# Reasoning: Wasps are often feared because of their sting and so running away from them would not be a favorite activity for anyone.
# This is why the sentence is a sarcasm.
# Literal translation: Today a swarm of wasps was chasing after me.
#
# Give literal translation of this simile: The demons were closing in, but I was like an old man on a park bench, feeding pigeons on a warm summer afternoon.
# Reasoning: The person is making a simile in which they are comparing their situation to a tranquil one.
# Literal translation: The demons were coming closer and closer, but I felt as peaceful as an elderly person feeding pigeons on a pleasant summer day in the park.
#
# -----------
# Give literal translation of this idiom: She herself was the one who had let the genie out of the bottle.
# Reasoning: To let the genie out of the bottle means to create or unleash something that has a huge impact and cannot be stopped or reversed and that is what she did in this context.
# This is why the sentence is a idiom.
# Literal translation: She herself was the one who had created a huge impact that could not be stopped or reversed.
#
# Give literal translation of this sarcasm: Yesterday, I felt thrilled because when I was cleaning the cupboards, I dropped an antique tea cup and it shattered
# Reasoning: Antique tea cups are usually expensive and dropping it and having it shatter would mean ruining something valuable which should not elicit a feeling of thrill but guilt.
# This is why the sentence is a sarcasm.
# Literal translation: Yesterday, when I was cleaning the cupboards, I dropped an antique tea cup and it shattered.
#
# Give literal translation of this simile: The bottle rolled off the table like a teardrop.
# Reasoning: To roll off a table with momentum like a teardrop means that it moves quickly, lightly and gracefully which is similar to the way a teardrop falls.
# This is why the sentence is a simile.
# Literal translation: The bottle moved quickly, lightly and gracefully off the table.
#
# -----------
# Give literal translation of this sarcasm: I feel wonderful that I am not eating healthy because I am ordering food almost every day now
# Reasoning: Eating unhealthy food often can cause someone to become obese and develop health problems, so not eating healthy because of a consistent pattern of ordering food is not a good thing.
# This is why the sentence is a sarcasm.
# Literal translation: I order food almost every day now and will never get healthy
#
# Give literal translation of this sarcasm: I feel just fantastic that I am not eating healthy because I am ordering food almost every day now.
# Reasoning: Eating unhealthy food often can cause someone to become obese and develop health problems, so not eating healthy because of a consistent pattern of ordering food is not a good thing.
# This is why the sentence is a sarcasm.
# Literal translation: I order food almost every day now and will never get healthy
#
# Give literal translation of this simile: You behave like you haven't eaten in a while.
# Reasoning: This simile describes someone as having a ravenous and desperate attitude, likely implying that the person is behaving in a frantic and desperate manner.
# Literal translation: You act as if you haven't eaten for a long time.
#
# -----------
# Give literal translation of this simile: He was looking like a wounded lion .
# Reasoning: A wounded lion is still a dangerous animal, so it would make sense that he would look fierce.
# This is why the sentence is a simile.
# Literal translation: He was looking fierce .
#
# Give literal translation of this simile: He was shy like a monkey.
# Reasoning: Monekys are not shy so this simile is depicting that the speaker is not shy at all
# This is why the sentence is a simile.
# Literal translation: He wasn't shy at all.
#
# Give literal translation of this simile: He was anxious like a lion.
# Reasoning: Lions are known to be powerful and imposing animals, so this simile is suggesting that the person was feeling very anxious.
# Literal translation: He was feeling very anxious.
#
# -----------
# Give literal translation of this simile: He was as graceful as a giraffe
# Reasoning: The simile is saying that he was very graceful, but the entailment is saying the opposite.
# This is why the sentence is a simile.
# Literal translation: He was not graceful
#
# Give literal translation of this simile: He worked as hard as dead slug
# Reasoning: Slugs are slimy creatures that are not known for their work ethic.
# This is why the sentence is a simile.
# Literal translation: He did not work hard
#
# Give literal translation of this metaphor: He fought as hard as an opossum
# Reasoning: Opossums are known for their defense mechanisms, making them difficult to defeat.
# This is why the sentence is a metaphor.
# Literal translation: He fought fiercely.
#
# -----------
# Give literal translation of this simile: He is as brave as a cow
# Reasoning: Cows are not known to be brave animals, so the simile is indicating that the person is not brave.
# This is why the sentence is a simile.
# Literal translation: he is a coward
#
# Give literal translation of this simile: He looked like a prowling animal .
# Reasoning: A prowling animal is one that is on the hunt, looking for its next meal much like someone primitive and primal.
# This is why the sentence is a simile.
# Literal translation: He looked primitive and primal .
#
# Give literal translation of this simile: He's like a pig in a wallow.
# Reasoning: Pigs tend to take pleasure in wallowing around in the mud, so this simile is indicating that the person takes pleasure in wallowing around in whatever activities they partake in.
# Literal translation: He takes pleasure in wallowing around.
#
# -----------
# Give literal translation of this sarcasm: I don't know how much longer I can put up with this joyous headache
# Reasoning: A headache is usually an indicator of an illness or an injury and is not something thats joyous.
# This is why the sentence is a sarcasm.
# Literal translation: This headache needs to go away.
#
# Give literal translation of this metaphor: My head lay in the crook of her neck.
# Reasoning: The crook of her neck is the indentation at the base of her neck where it meets her shoulder, so resting my head there would mean that my head was lying in that area.
# This is why the sentence is a metaphor.
# Literal translation: My head was resting in the crook of her neck.
#
# Give literal translation of this simile: After 10 minutes your head becomes like spinning cotton candy.
# Reasoning: Spinning cotton candy is something that quickly twirls in a circular motion and usually come in beautiful shapes and colors.
# This is why the sentence is a simile.
# Literal translation: After 10 minutes your head feels like it is spinning in a whirling motion.
#
# -----------
# Give literal translation of this idiom: that makes two of us.
# Reasoning: The idiom "that makes two of us" means "the same is true for me". So in this context, the speaker is saying that they feel the same way.
# This is why the sentence is a idiom.
# Literal translation: I feel exactly the same way.
#
# Give literal translation of this simile: I let my body like a rag doll.
# Reasoning: A rag doll is an inanimate object that does not have the ability to hold itself up, so by saying that her body was like a rag doll, it is implied that she was not able to hold herself up either and was limp.
# This is why the sentence is a simile.
# ...
# This is why the sentence is a idiom.
# Literal translation: The only question was, how would she repair the relationship with him, and would he want her back after she had seemed to side with uncle hugh?
#
# Give literal translation of this idiom: She wouldn't have been able to cut the mustard in the talkies.
# Reasoning: To cut the mustard means to work or operate in a satisfactory manner, which is what she would have been able to do in the talkies.
# This is why the sentence is a idiom.
# Literal translation: She wouldn't have been able to satisfactorily work or operate in the talkies.
#
# Give literal translation of this idiom: But Laura was a piranha; she'd have chewed him down to the bone if he had let her.
# Reasoning: To chew someone down to the bone means to completely deplete their energy or patience, which is what Laura would have done if he had let her.
# This is why the sentence is a idiom.
# Literal translation: But Laura was aggressive; she would have completely depleted his energy or patience if he had let her.
#
# -----------
# Give literal translation of this simile: His sensitive ears picked up every sound, but it was like a library on friday night
# Reasoning: On a Friday night, libraries are still and quiet, implying it was quiet.
# This is why the sentence is a simile.
# Literal translation: his sensitive ears picked up every sound, it was still quiet.
#
# Give literal translation of this idiom: But still, hearing it all poured out so short and sweet when so much was on the line was dizzying.
# Reasoning: To be short and sweet is to be brief while still being satisfying or to the point, and in this context the person is pourign out their feelings concisely and satisfyingly.
# This is why the sentence is a idiom.
# Literal translation: But still, hearing it all poured out so concisely and satisfyingly when so much was on the line was dizzying.
#
# Give literal translation of this idiom: It wasn't glib or run of the mill ,it didn't go in one ear and out the other.
# Reasoning: To be glib is to have an offhand, cutting remark and run of the mill is to be nothing out of the ordinary. To go in one ear and out the other is to not being retained or remembered.
# This is why the sentence is an idiom.
# Literal translation: It wasn't an offhand or plain remark, it was not forgotten.
#
# -----------
# Give literal translation of this idiom: His memory slipped away from most who had grieved; legacy left to gather dust.
# Reasoning: To gather dust means to be unused or forgotten, and in this sentence the legacy is being left to become forgotten.
# This is why the sentence is a idiom.
# Literal translation: His memory slipped away from most who had grieved; legacy left to become forgotten and unused.
#
# Give literal translation of this simile: He seemed like a dark and elemental spirit .
# Reasoning: An elemental spirit is a being that is often seen as dark and dangerous and very ugly.
# This is why the sentence is a simile.
# Literal translation: He seemed unnecessarily ugly .
#
# Give literal translation of this idiom: So impassive and peculiar had the Collector become , so obviously on the verge , everyone thought so ( you would have thought so yourself if you had seen him at this time ) , of giving up the ghost , that his face was scrutinized more closely than ever for any trace of remorse as the gorse bruiser was carried out .
# Reasoning: To give up the ghost means to die, and this sentence is saying that the person was scrutinized more closely than ever for any signs of regret as they carried the gorse bruiser out.
# This is why the sentence is an idiom.
# Literal translation: So unmoving and strange had the Collector become , so clearly on the edge , everyone thought so ( you would have thought so yourself if you had seen him at this time ) , of passing away , that his face was examined more carefully than ever for any signs of remorse as the gorse bruiser was taken out.
#
# -----------
# Give literal translation of this idiom: It was also an opportunity for you to get your feet wet.
# Reasoning: To get your feet wet means to start doing something that is new for you, so in this sentence it is an opportunity to try something new.
# This is why the sentence is a idiom.
# Literal translation: It was also an opportunity for you to try something new.
#
# Give literal translation of this simile: The blood that came out was like the night
# Reasoning: The color black is often associated with the night, so the blood is black.
# This is why the sentence is a simile.
# Literal translation: The blood that oozed out was black.
#
# Give literal translation of this idiom: Great to see young blood getting their feet wet.
# Reasoning: To get your feet wet means to start doing something that is new for you, so in this sentence it is referring to the younger generation trying something new.
# This is why the sentence is an idiom.
# Literal translation: It's great to see the younger generation trying something new.
#
# -----------
# Give literal translation of this idiom: You must not have been up to snuff for her to run so fast.
# Reasoning: To be up to snuff means to be as good as is required, and in this context the speaker wasn't good enough for the other person.
# This is why the sentence is a idiom.
# Literal translation: You must not have been good enough for her to run so fast.
#
# Give literal translation of this metaphor: Calm down - there's no need to get all steamed up about it.
# Reasoning: All steamed up means to be very angry or upset about something.
# This is why the sentence is a metaphor.
# Literal translation: Calm down - there's no need to get angry about it.
#
# Give literal translation of this idiom: You're just not up to snuff.
# Reasoning: To be up to snuff means to be as good as is required.
# In this context the speaker is implying that the person is not good enough.
# This is why the sentence is an idiom.
# Literal translation: You're just not good enough.
#
# -----------
# Give literal translation of this idiom: Now, cut the crap.
# Reasoning: To cut the crap means to get to the point, which is what the speaker is telling the other person to do.
# This is why the sentence is a idiom.
# Literal translation: Now, get to the point.
#
# Give literal translation of this metaphor: She is fishing in troubled waters.
# Reasoning: The phrase troubled waters is often used to describe a state of confusion or chaos. In this sentence, the speaker is saying that the person is living in a confused state.
# This is why the sentence is a metaphor.
# Literal translation: She is living in a confused state.
#
# Give literal translation of this idiom: Let's cut the crap,said webb's fishing companion.
# Reasoning: To cut the crap means to get to the point, which is what the speaker is telling the other person to do.
# This is why the sentence is a idiom.
# Literal translation: Let's get to the point,said webb's fishing companion.
#
# -----------
# Give literal translation of this metaphor: The sales tax is absorbed into the state income tax.
# Reasoning: Here absorbed is used to mean that the sales tax is added to the income tax.
# This is why the sentence is a metaphor.
# Literal translation: The sales tax is incorporated into the state income tax .
#
# Give literal translation of this metaphor: The tax cut will fertilize the economy.
# Reasoning: Fertilize means to make something grow or develop.
# This is why the sentence is a metaphor.
# Literal translation: The tax cut will definitely help the economy.
#
# Give literal translation of this idiom: A general principle for an efficient tax system is to collect a given amount of revenue (corresponding in the long run to the government ’s spending) in a way that causes as little distortion as possible to the overall economy.
# Reasoning: This is an idiom because it expresses a general idea rather than a literal meaning.
# Literal translation: A rule for an effective tax system is to acquire the required amount of profits (closely following the government's costs) without significantly affecting the general economy.
#
# -----------
# Give literal translation of this idiom: Let's just leave it at that.
# Reasoning: To leave it at that means to take no further action, so in this context they are suggesting to stop and not continue.
# This is why the sentence is a idiom.
# Literal translation: Let's just stop here and not continue any further.
#
# Give literal translation of this metaphor: This story will grab you.
# Reasoning: when you are hooked up on something it means you are interested in it.
# This is why the sentence is a metaphor.
# Literal translation: This story will hook you up.
#
# Give literal translation of this idiom: Come take it from me.
# Reasoning: When a person take something from another person it means they are getting advice or guidance.
# This is why the sentence is an idiom.
# Literal translation: Come get advice from me.
#
# -----------
# Give literal translation of this metaphor: He said the leaders will have to deal with an ocean of resentment.
# Reasoning: The phrase an ocean of resentment means a lot of resentment.
# This is why the sentence is a metaphor.
# Literal translation: He said that the leaders will have to deal with a lot of resentment.
#
# Give literal translation of this metaphor: The conversation gravitated towards politics.
# Reasoning: Gravitated means to move towards something.
# This is why the sentence is a metaphor.
# Literal translation: The entire conversation shifted to politics.
#
# Give literal translation of this idiom: The talks came to grief after the separatists insisted that the government , or perhaps the ruling Socialist party , should publicly acknowledge that its representatives had agreed to negotiate with ETA on the Basque country 's political future .
# Reasoning: The phrase came to grief means to fail or be unsuccessful.
# This is why the sentence is an idiom.
# Literal translation: The talks were unsuccessful after the separatists insisted that the government, or perhaps the ruling Socialist party, should publicly acknowledge that its representatives had agreed to negotiate with ETA on the Basque country's political future.
#
# -----------
# Give literal translation of this idiom: You always manage to put your foot in it when it comes to women pat!
# Reasoning: To put your foot in it means to say something foolish or offensive, which is what he always manages to do around women.
# This is why the sentence is a idiom.
# Literal translation: You always manage to say something foolish, tactless, or offensive when it comes to women pat!
#
# Give literal translation of this simile: As her fingertips touch the apparition, the sensation overtaking her is like a cool wash cloth on a feverish head.
# Reasoning: A cool wash cloth on a feverish head would be a very comforting sensation, so the simile is used to convey that the email contact was also comforting.
# This is why the sentence is a simile.
# Literal translation: As she felt her fingertips touch the apparition, the sensation was rather comforting.
#
# Give literal translation of this idiom: I know that woman too well to ever want to lay a finger on her, okay?
# Reasoning: This is an idiom that essentially means "I know her too well to ever want to get involved with her (romantically)"
# Literal translation: I am very familiar with that woman so I have no interest in getting entangled with her, all right?
#
# -----------
# Give literal translation of this idiom: "Good enough" Grond said now lead the way.
# Reasoning: To lead the way means to guide or direct someone somewhere by proceeding ahead of them, which is what Grond asked the other person to do.
# This is why the sentence is a idiom.
# Literal translation: "Good enough" Grond said now go ahead of me and show me the way.
#
# Give literal translation of this idiom: He turned back and said, "I am sort of, oh, what do you say? A jack of all trades."
# Reasoning: A jack of all trades is a person who is skilled in many different areas, which is what he is saying he is.
# This is why the sentence is a idiom.
# Literal translation: He turned back and said, "I am sort of, oh, what do you say? A versatile individual."
#
# Give literal translation of this idiom: ‘ That spoke volumes for the character as well as quality of our squad — no matter what others might think.’
# Reasoning: This idiom means to convey something important with very few words. This is what the sentence is saying about their team, that no matter what others think their quality speaks for itself.
# This is why the sentence is a idiom.
# Literal translation: ‘That communicated a lot about the personality as well as excellence of our team — regardless of what other people might think.’
#
# -----------
# Give literal translation of this metaphor: The bridge towers over the river.
# Reasoning: Towers over means that the bridge is standing over than the river.
# This is why the sentence is a metaphor.
# Literal translation: Overlooking the river is the bridge.
#
# Give literal translation of this sarcasm: I recently lost my job and feel like the world is fair
# Reasoning: Losing a job is always unfortunate as it leads to one being unemployed and so feeling like the world is fair because of it is absurd.
# This is why the sentence is a sarcasm.
# Literal translation: I recently lost my job and I feel horrible.
#
# Give literal translation of this idiom: It 's all water under the bridge ; you do n't want to hear it — I 'm sorry if you feel I 've been unfair to you .
# Reasoning: This idiom is commonly used to mean that something has already happened and so can't be undone.
# Literal translation: It has already occurred and it cannot be changed; you do not wish to hear it - I apologize if you think I was not fair to you.
#
# -----------
# Give literal translation of this metaphor: In addition, the storm trampled the town.
# Reasoning: The storm trampled the town meaning completely destroyed everything in its path.
# This is why the sentence is a metaphor.
# Literal translation: In addition, the disastrous storm, destroyed the town.
#
# Give literal translation of this idiom: The place is off the beaten track, very peaceful.
# Reasoning: To be off the beaten track means to be away from the frequently traveled routes, and in this context the place is also described as being little-known or in a remote area.
# This is why the sentence is a idiom.
# Literal translation: The place is secluded, away from the frequently traveled routes and not well-known, very peaceful.
#
# Give literal translation of this idiom: The road and railway from Mallaig go south hand in hand along the coast to Keppoch , famed for its glorious seascapes , and Arisaig , a small village beloved of discerning holidaymakers who find there tranquillity in alliance with an enchanting coast .
# Reasoning: Hand in hand means to be together, linked or associated in some way. This is why the sentence is a idiom.
# Literal translation: The road and railway from Mallaig run side by side along the coast to Keppoch, well-known for its beautiful seascapes, and Arisaig, a tiny town favored by those who appreciate tranquility in addition to the mesmerizing coast.
#
# -----------
# Give literal translation of this simile: He'd gotten near enough to her once, trapping her in a corner of her gallery, to catch a fragrance that smelled like an exotic tropical flower .
# Reasoning: A tropical flower would have a rich fragrance, hence the simile.
# This is why the sentence is a simile.
# Literal translation: He had gotten close enough to her to trap her in a corner of her gallery, and he caught a whiff of her wonderfully rich fragrance.
#
# Give literal translation of this simile: Her face was already like a beet.
# Reasoning: Beets are a red vegetable, so the simile is saying that her face was already red.
# This is why the sentence is a simile.
# Literal translation: Her face was already red
#
# Give literal translation of this idiom: Flora pulled a face.
# Reasoning: "Pulling a face" is an idiom that means making an expression of disgust or displeasure.
# Literal translation: Flora made an expression of disgust or displeasure.
#
# -----------
# DONE!

# %%
test_df
# Out:
#      Unnamed: 0  Index                                         Hypothesis  \
# 0           331     50  I heard a knock on my door at 2 am in the morn...
# 1           233   1630  I was very proud of my sense of judgement when...
# 2            66   2112  I adore it when people blast their music durin...
# 3           374   1833  I am pleased because the last thing I need is ...
# 4           452   1057  I was extremely happy to find out that all my ...
# ..          ...    ...                                                ...
# 395         332   3260  I know that woman too well to ever want to lay...
# 396         527   7919  ‘ That spoke volumes for the character as well...
# 397         569   6303  It 's all water under the bridge ; you do n't ...
# 398         222   6481  The road and railway from Mallaig go south han...
# 399         306   7969                               Flora pulled a face.
#
#                                                Premise     Type  \
# 0    I heard a knock on my door at 2 am in the morn...  Sarcasm
# 1    I was seriously doubting my sense of judgement...  Sarcasm
# 2    I despise it when people blast their music dur...  Sarcasm
# 3      I've been getting really bad headaches recently  Sarcasm
# 4    I was extremely broken to find out that all my...  Sarcasm
# ..                                                 ...      ...
# 395  I know that woman too well to ever want to hur...    Idiom
# 396  ‘ That provided substantial information for th...    Idiom
# 397  It 's all in the past ; you do n't want to hea...    Idiom
# 398  The road and railway from Mallaig go south in ...    Idiom
# 399  Flora made a facial expression that shows disl...    Idiom
#
#                                            Explanation          Label  \
# 0    Unknown people knocking on someone's door at 2...  Contradiction
# 1    : Someone who is admired for their great visio...  Contradiction
# 2    People blasting their music during the wee hou...  Contradiction
# 3    Having a headache makes someone's day worse as...  Contradiction
# 4    Studying for an annual exam is often a waste o...  Contradiction
# ..                                                 ...            ...
# 395  To lay a finger on someone usually refers to h...     Entailment
# 396                                                NaN     Entailment
# 397                                                NaN     Entailment
# 398                                                NaN     Entailment
# 399                                                NaN     Entailment
#
#     SarcasmSimilarity Source  \
# 0                 UNQ  FLUTE
# 1                 UNQ  FLUTE
# 2                 UNQ  FLUTE
# 3                 UNQ  FLUTE
# 4                 UNQ  FLUTE
# ..                ...    ...
# 395               UNQ  FLUTE
# 396               NaN  IMPLI
# 397               NaN  IMPLI
# 398               NaN  IMPLI
# 399               NaN  IMPLI
#
#                                                 Output
# 0     Hearing a knock on the door at 2 am in the mo...
# 1     This statement is ironic because it would be ...
# 2     Playing loud music in the middle of the night...
# 3     A headache is really a painful and unpleasant...
# 4     Studying for an annual exam is often a necess...
# ..                                                 ...
# 395   This is an idiom that essentially means "I kn...
# 396   This idiom means to convey something importan...
# 397   This idiom is commonly used to mean that some...
# 398   Hand in hand means to be together, linked or ...
# 399   "Pulling a face" is an idiom that means makin...
#
# [400 rows x 10 columns]

# %%
for ind in test_df.index:
  lit_output = test_df['Output'][ind]
  lit_output = lit_output.strip()
  reasoning = lit_translation = ''
  if re.search("literal translation:", lit_output, re.IGNORECASE):
    reasoning, lit_translation = re.split("literal translation:", lit_output, flags=re.IGNORECASE)
    reasoning = reasoning.strip()
    lit_translation = lit_translation.strip()
  else:
    reasoning = lit_translation = lit_output
  test_df.loc[ind, ['Reasoning']] = reasoning
  test_df.loc[ind, ['Literal Translation']] = lit_translation

# %%
test_df
# Out:
#      Unnamed: 0  Index                                         Hypothesis  \
# 0           331     50  I heard a knock on my door at 2 am in the morn...
# 1           233   1630  I was very proud of my sense of judgement when...
# 2            66   2112  I adore it when people blast their music durin...
# 3           374   1833  I am pleased because the last thing I need is ...
# 4           452   1057  I was extremely happy to find out that all my ...
# ..          ...    ...                                                ...
# 395         332   3260  I know that woman too well to ever want to lay...
# 396         527   7919  ‘ That spoke volumes for the character as well...
# 397         569   6303  It 's all water under the bridge ; you do n't ...
# 398         222   6481  The road and railway from Mallaig go south han...
# 399         306   7969                               Flora pulled a face.
#
#                                                Premise     Type  \
# 0    I heard a knock on my door at 2 am in the morn...  Sarcasm
# 1    I was seriously doubting my sense of judgement...  Sarcasm
# 2    I despise it when people blast their music dur...  Sarcasm
# 3      I've been getting really bad headaches recently  Sarcasm
# 4    I was extremely broken to find out that all my...  Sarcasm
# ..                                                 ...      ...
# 395  I know that woman too well to ever want to hur...    Idiom
# 396  ‘ That provided substantial information for th...    Idiom
# 397  It 's all in the past ; you do n't want to hea...    Idiom
# 398  The road and railway from Mallaig go south in ...    Idiom
# 399  Flora made a facial expression that shows disl...    Idiom
#
#                                            Explanation          Label  \
# 0    Unknown people knocking on someone's door at 2...  Contradiction
# 1    : Someone who is admired for their great visio...  Contradiction
# 2    People blasting their music during the wee hou...  Contradiction
# 3    Having a headache makes someone's day worse as...  Contradiction
# 4    Studying for an annual exam is often a waste o...  Contradiction
# ..                                                 ...            ...
# 395  To lay a finger on someone usually refers to h...     Entailment
# 396                                                NaN     Entailment
# 397                                                NaN     Entailment
# 398                                                NaN     Entailment
# 399                                                NaN     Entailment
#
#     SarcasmSimilarity Source  \
# 0                 UNQ  FLUTE
# 1                 UNQ  FLUTE
# 2                 UNQ  FLUTE
# 3                 UNQ  FLUTE
# 4                 UNQ  FLUTE
# ..                ...    ...
# 395               UNQ  FLUTE
# 396               NaN  IMPLI
# 397               NaN  IMPLI
# 398               NaN  IMPLI
# 399               NaN  IMPLI
#
#                                                 Output  \
# 0     Hearing a knock on the door at 2 am in the mo...
# 1     This statement is ironic because it would be ...
# 2     Playing loud music in the middle of the night...
# 3     A headache is really a painful and unpleasant...
# 4     Studying for an annual exam is often a necess...
# ..                                                 ...
# 395   This is an idiom that essentially means "I kn...
# 396   This idiom means to convey something importan...
# 397   This idiom is commonly used to mean that some...
# 398   Hand in hand means to be together, linked or ...
# 399   "Pulling a face" is an idiom that means makin...
#
#                                              Reasoning  \
# 0    Hearing a knock on the door at 2 am in the mor...
# 1    This statement is ironic because it would be m...
# 2    Playing loud music in the middle of the night ...
# 3    A headache is really a painful and unpleasant ...
# 4    Studying for an annual exam is often a necessa...
# ..                                                 ...
# 395  This is an idiom that essentially means "I kno...
# 396  This idiom means to convey something important...
# 397  This idiom is commonly used to mean that somet...
# 398  Hand in hand means to be together, linked or a...
# 399  "Pulling a face" is an idiom that means making...
#
#                                    Literal Translation
# 0    I was filled with dread when I heard a knock o...
# 1    I was embarrassed of my decision making when I...
# 2    I hate when people play music at 3am in the mi...
# 3    I really don't want to get a headache today be...
# 4    I was extremely disappointed to find out that ...
# ..                                                 ...
# 395  I am very familiar with that woman so I have n...
# 396  ‘That communicated a lot about the personality...
# 397  It has already occurred and it cannot be chang...
# 398  The road and railway from Mallaig run side by ...
# 399  Flora made an expression of disgust or displea...
#
# [400 rows x 12 columns]

# %%
def calculate_bleurt(df):
  # BLEURT calculation
  scorer = bleurt_score.BleurtScorer('/content/BLEURT-20')
  bleurt_scores = scorer.score(references=df['Premise'], candidates=df['Literal Translation'])
  print(bleurt_scores)
  return bleurt_scores

def calculate_bertscore(df):
  # BERTScore calculation
  bertscore = load_metric('bertscore')
  bert_scores = bertscore.compute(predictions=df['Literal Translation'], references=df['Premise'], lang="en")
  print(bert_scores['f1'])
  return bert_scores['f1']

def calculate_littransscore(bert_scores, bleurt_scores):
  lit_trans_scores = []
  for ind in range(len(bleurt_scores)):
    lit_trans_scores.append((bert_scores[ind] + bleurt_scores[ind]) * 50.0)
  return lit_trans_scores

# %%
bleurt_scores = calculate_bleurt(test_df)
# Out:
# [0.6178280115127563, 0.6765174865722656, 0.7004265189170837, 0.46850693225860596, 0.8834017515182495, 0.8567996025085449, 0.7406611442565918, 0.7667922973632812, 0.6042110323905945, 0.8005295395851135, 0.7726153135299683, 0.6836861371994019, 0.677539050579071, 0.7678931951522827, 0.8541590571403503, 0.7248182892799377, 0.8487015962600708, 0.7059642672538757, 0.6895152926445007, 0.631512463092804, 0.8042793869972229, 0.6896601319313049, 0.9113443493843079, 0.6894431114196777, 0.7652260661125183, 0.8794838786125183, 0.7452359795570374, 0.5509359240531921, 0.8178381323814392, 0.5757505893707275, 0.5300754308700562, 0.770721435546875, 0.610717236995697, 0.6190123558044434, 0.7171847820281982, 0.8315653204917908, 0.6932161450386047, 0.5826987624168396, 0.7987812161445618, 0.5733698010444641, 0.8765395283699036, 0.721207320690155, 0.7118167877197266, 0.8316414952278137, 0.7647915482521057, 0.712286114692688, 0.7023654580116272, 0.7694755792617798, 0.6437788605690002, 0.696672260761261, 0.8001008629798889, 0.5675579905509949, 0.8854626417160034, 0.6301441788673401, 0.5980111956596375, 0.8593003153800964, 0.6052486300468445, 0.6822234392166138, 0.6795715689659119, 0.9861801266670227, 0.5630627870559692, 0.877907931804657, 0.7679478526115417, 0.8731775879859924, 0.6500630974769592, 0.7039074301719666, 0.7436881065368652, 0.8437254428863525, 0.6380161643028259, 0.7575476765632629, 0.679319441318512, 0.6898177862167358, 0.9508077502250671, 0.6743795871734619, 0.963959276676178, 0.7096867561340332, 0.7401140332221985, 0.572921097278595, 0.5277419686317444, 0.8350741267204285, 0.6343201398849487, 0.926975667476654, 0.778692901134491, 0.7469621300697327, 0.585639238357544, 0.7726898789405823, 0.7692317962646484, 0.7013287544250488, 0.863183319568634, 0.8561363816261292, 0.5401975512504578, 0.5565803050994873, 0.8212175369262695, 0.8232728838920593, 0.5378089547157288, 0.8148568868637085, 0.8889632821083069, 0.8578180074691772, 0.6547566652297974, 0.8735836148262024, 0.6488379240036011, 0.4535370469093323, 0.5652536153793335, 0.5699268579483032, 0.7480084896087646, 0.663866400718689, 0.41275614500045776, 0.624747097492218, 0.7447096109390259, 0.6909456253051758, 0.9387449026107788, 0.6375987529754639, 0.6123401522636414, 0.3468806743621826, 0.5916372537612915, 0.78980952501297, 0.47936975955963135, 0.6151487231254578, 0.372266948223114, 0.24967145919799805, 0.5735805034637451, 0.7215428948402405, 0.514280378818512, 0.5407280921936035, 0.5968357920646667, 0.6521106958389282, 0.5873517394065857, 0.639752984046936, 0.6379318237304688, 0.5467517971992493, 0.49043524265289307, 0.6929545402526855, 0.5783288478851318, 0.5593288540840149, 0.6507530212402344, 0.5040769577026367, 0.40404045581817627, 0.6696205139160156, 0.578327476978302, 0.7007504105567932, 0.5965281128883362, 0.4212214946746826, 0.3590468168258667, 0.688395082950592, 0.3256815969944, 0.629682719707489, 0.9784730076789856, 0.5625238418579102, 0.8263146281242371, 0.41545480489730835, 0.8000946640968323, 0.4431096911430359, 0.4682155251502991, 0.510205090045929, 0.3500230610370636, 0.37769508361816406, 0.7174836993217468, 0.5020096898078918, 0.30526840686798096, 0.5911977291107178, 0.5675007700920105, 0.601470410823822, 0.5227563381195068, 0.5904242992401123, 0.5879971385002136, 0.5407995581626892, 0.8269321322441101, 0.5851424336433411, 0.7579569220542908, 0.7342570424079895, 0.36920833587646484, 0.48217707872390747, 0.5544955134391785, 0.620964527130127, 0.44741761684417725, 0.5257572531700134, 0.6032996773719788, 0.5677123069763184, 0.6719629168510437, 0.674371063709259, 0.6468044519424438, 0.4325868487358093, 0.5289153456687927, 0.5985649824142456, 0.6747260093688965, 0.694889485836029, 0.4953138828277588, 0.49395954608917236, 0.6903128027915955, 0.7307578921318054, 0.6787384748458862, 0.5126463770866394, 0.36285871267318726, 0.8294686675071716, 0.7438628077507019, 0.6940019130706787, 0.8210071921348572, 0.6032123565673828, 0.6349548101425171, 0.7088701725006104, 0.6806580424308777 ...

# %%
bert_scores = calculate_bertscore(test_df)
# Out:
# <ipython-input-57-f48c1ffe6b80>:10: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   bertscore = load_metric('bertscore')
# Downloading builder script:   0%|          | 0.00/2.92k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.43G [00:00<?, ?B/s]
# [0.9489826560020447, 0.9293994307518005, 0.9524160623550415, 0.8876468539237976, 0.9887697696685791, 0.9710198640823364, 0.9592796564102173, 0.940705418586731, 0.9236050248146057, 0.9524333477020264, 0.9373872876167297, 0.9161515235900879, 0.9169740676879883, 0.9394298791885376, 0.9969666600227356, 0.9265087246894836, 0.9780773520469666, 0.9309607148170471, 0.9130401611328125, 0.9184983372688293, 0.9890386462211609, 0.9533452987670898, 0.990375816822052, 0.9515777230262756, 0.9767053127288818, 0.9938803911209106, 0.9516685009002686, 0.907016396522522, 0.9837223887443542, 0.9126981496810913, 0.9464542865753174, 0.9387954473495483, 0.9567882418632507, 0.9298005700111389, 0.9302237033843994, 0.9887343645095825, 0.9283172488212585, 0.9141194224357605, 0.9665529727935791, 0.9085427522659302, 0.9754564166069031, 0.9438025951385498, 0.9434091448783875, 0.9820259809494019, 0.9733522534370422, 0.9274487495422363, 0.9080031514167786, 0.9578512907028198, 0.9475492238998413, 0.9192537069320679, 0.9751437306404114, 0.914298415184021, 0.9884287714958191, 0.937970757484436, 0.9147825241088867, 0.9906185865402222, 0.902404248714447, 0.9402278065681458, 0.9349162578582764, 0.9936793446540833, 0.9322867393493652, 0.9954966306686401, 0.964158833026886, 0.9872527122497559, 0.9444235563278198, 0.9528611898422241, 0.9756916761398315, 0.9870728850364685, 0.8988808393478394, 0.970050036907196, 0.9304913282394409, 0.8994839787483215, 0.9930736422538757, 0.9259098172187805, 0.9879298806190491, 0.9711954593658447, 0.9456939101219177, 0.9148322343826294, 0.9050754308700562, 0.9803577661514282, 0.9244692325592041, 0.9942324757575989, 0.9707328677177429, 0.9846239686012268, 0.9026631116867065, 0.9155942797660828, 0.9505172967910767, 0.9422487616539001, 0.9836404323577881, 0.9853911399841309, 0.9135943651199341, 0.9056265354156494, 0.9811611175537109, 0.9808757305145264, 0.8898444771766663, 0.9901508688926697, 0.9862940311431885, 0.982671320438385, 0.9185284376144409, 0.9930373430252075, 0.9638795256614685, 0.8965977430343628, 0.914076030254364, 0.9061044454574585, 0.9671136736869812, 0.843066394329071, 0.9356689453125, 0.9260644316673279, 0.9557658433914185, 0.9237229824066162, 0.9756956100463867, 0.9396835565567017, 0.8886206150054932, 0.8840624690055847, 0.8924857974052429, 0.9690866470336914, 0.8901204466819763, 0.9228304624557495, 0.8993459939956665, 0.8661785125732422, 0.9029231667518616, 0.9527958631515503, 0.9178165793418884, 0.912743330001831, 0.9180232286453247, 0.9413490891456604, 0.9071846604347229, 0.9198854565620422, 0.9049454927444458, 0.923511803150177, 0.8746100664138794, 0.9158535003662109, 0.9480641484260559, 0.8986801505088806, 0.9344382882118225, 0.9089260101318359, 0.8739104270935059, 0.9239420294761658, 0.9039803743362427, 0.9600405693054199, 0.8697187304496765, 0.9271407723426819, 0.8968695402145386, 0.9304633140563965, 0.870347797870636, 0.9246106743812561, 0.9999997615814209, 0.9275186657905579, 0.9707154631614685, 0.8849970698356628, 0.9751721620559692, 0.907581627368927, 0.907281756401062, 0.9323435425758362, 0.8941779732704163, 0.9021340012550354, 0.9375302791595459, 0.9033197164535522, 0.8961467146873474, 0.9568014740943909, 0.8805978894233704, 0.9062777757644653, 0.9399746656417847, 0.9032022953033447, 0.9248974323272705, 0.9230135083198547, 0.9533645510673523, 0.9444919228553772, 0.9707779884338379, 0.9194305539131165, 0.8943976759910583, 0.9058899283409119, 0.9435496926307678, 0.9397939443588257, 0.8798747062683105, 0.9287630915641785, 0.9126646518707275, 0.938656747341156, 0.9379857182502747, 0.9530460238456726, 0.9420652389526367, 0.9085422158241272, 0.9188559651374817, 0.9088909029960632, 0.9291015267372131, 0.9245110750198364, 0.8997396230697632, 0.9009327292442322, 0.9170026183128357, 0.9502680897712708, 0.933902382850647, 0.9137786626815796, 0.8806307911872864, 0.9765854477882385, 0.9664374589920044, 0.9294543266296387, 0.9833782315254211, 0.9494330883026123, 0.9433667659759521, 0.9304265975952148, 0.9358503818511963,  ...

# %%
print("Range of BLEURT: ")
print(min(bleurt_scores))
print(max(bleurt_scores), end='\n')

print("Range of BERTScore: ")
print(min(bert_scores))
print(max(bert_scores), end='\n')
# Out:
# Range of BLEURT:
# 0.24967145919799805
# 1.003772497177124
# Range of BERTScore:
# 0.843066394329071
# 1.0

# %%
# Compute literal translation score
lit_trans_scores = calculate_littransscore(bert_scores, bleurt_scores)
test_df['Score'] = lit_trans_scores
test_df['BLEURT'] = bleurt_scores
test_df['BERT'] = bert_scores

lit_trans_scores_scores_metaphor = test_df.groupby('Type').get_group('Metaphor')['Score']
lit_trans_scores_scores_idiom = test_df.groupby('Type').get_group('Idiom')['Score']
lit_trans_scores_scores_simile = test_df.groupby('Type').get_group('Simile')['Score']
lit_trans_scores_scores_sarcasm = test_df.groupby('Type').get_group('Sarcasm')['Score']

print(min(lit_trans_scores))
print(max(lit_trans_scores))

print('Average literal translation score for metaphor: %d' %(sum(lit_trans_scores_scores_metaphor)/len(lit_trans_scores_scores_metaphor)))
print('Average literal translation score for idiom: %d' %(sum(lit_trans_scores_scores_idiom)/len(lit_trans_scores_scores_idiom)))
print('Average literal translation score for simile: %d' %(sum(lit_trans_scores_scores_simile)/len(lit_trans_scores_scores_simile)))
print('Average literal translation score for sarcasm: %d' %(sum(lit_trans_scores_scores_sarcasm)/len(lit_trans_scores_scores_sarcasm)))
# Out:
# 55.79249858856201
# 100.1886248588562
# Average literal translation score for metaphor: 80
# Average literal translation score for idiom: 82
# Average literal translation score for simile: 75
# Average literal translation score for sarcasm: 84

# %%
# Export results
test_zero_shot = test_df.loc[:,['Hypothesis','Literal Translation','Premise','Reasoning','Score','BLEURT','BERT','Type','Source']]
test_zero_shot.to_csv('../Results/Prompting/chain_of_thought_results_knn.csv')
